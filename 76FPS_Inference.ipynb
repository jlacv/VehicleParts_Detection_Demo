# %% [markdown]
# <a href="https://colab.research.google.com/github/aymanemoataz/Monk-AI---Data-quality-assessment/blob/master/76FPS_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Get the weights of your trained model using (the 11k_model notebook) our download weights in the results_11kmodel/weights folder in the link below :*
#
# https://drive.google.com/drive/folders/1ZWUDJJYCMmj0SdNfSgjKnaJIhoI9xRBn

# %%
# checking the GPU :

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Dec 29 12:04:17 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !git clone https://github.com/ultralytics/yolov5  
# %cd yolov5
# !git reset --hard 886f1c03d839575afecb059accf74296fad395b6
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10344, done.
# remote: Total 10344 (delta 0), reused 0 (delta 0), pack-reused 10344
# Receiving objects: 100% (10344/10344), 10.58 MiB | 32.62 MiB/s, done.
# Resolving deltas: 100% (7141/7141), done.
# /content/yolov5
# HEAD is now at 886f1c0 DDP after autoanchor reorder (#2421)

# %%
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch
# Out:
#      |████████████████████████████████| 596 kB 5.1 MB/s

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %% [markdown]
# Upload your weights and use them for inference

# %%
# !python detect.py --weights /content/elevenk.pt --img 416 --conf 0.4 --source /content/car_snow_night1.mp4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=416, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='/content/car_snow_night1.mp4', update=False, view_img=False, weights=['/content/elevenk.pt'])
# YOLOv5 v4.0-126-g886f1c0 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 232 layers, 7265397 parameters, 0 gradients, 16.8 GFLOPS
# video 1/1 (1/2774) /content/car_snow_night1.mp4: 256x416 1 door, 1 fender, 1 light, 2 wheels, Done. (0.033s)
# ...

# %%
FPS2 = (1/ 0.013)
print(FPS2)
# Out:
# 76.92307692307692
